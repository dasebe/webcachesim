# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from glob import glob
import pathlib
import common

FONT_SIZE = 15
plt.rc('font', size=FONT_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=FONT_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=FONT_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_SIZE)    # legend fontsize
plt.rc('figure', titlesize=FONT_SIZE)  # fontsize of the figure title
matplotlib.rc('lines', linewidth=3)

# %%
objective = 'byte_hit_rate'

# %%
marker_map = {
    'Belady': '1',
    'S4LRU': 'd',
    'LFUDA': 'o',
    'Adaptive-TinyLFU': 'v',
#     'BeladySample': '#000080',
    'GDBT': '*',
#     'LR': 'r',
    'LRUK': '>',
    
    'GDSF': '8',
    'LRU': 's',
    
#     'Hyperbolic': 'chartreuse',
    'LeCaR': 'p',
    'AdaptSize': 'P',
    'LHD': '+',
    'GDWheel': 'x',
    
}

# %%
color_map = {
    'Belady': 'k',
#     'BeladySample': '#000080',
    'GDBT': 'b',
#     'LR': 'r',
    'LRUK': 'g',
    'LFUDA': '#808080',
    'GDSF': 'm',
    'LRU': '#59b300',
    'S4LRU': 'r',
#     'Hyperbolic': 'chartreuse',
    'LeCaR': '#ed740b',
    'AdaptSize': '#669999',
    'LHD': '#336699',
    'GDWheel': '#000080',
    'Adaptive-TinyLFU': 'burlywood',
}

# %%
trace_map = {
    'traceHK.tr': 'Akamai HK',
    'traceUS.tr': 'Akamai US',
    'wc200m.tr': 'Wikipedia',
    'wc400m.tr': 'Wikipedia',
    'memc_200m.tr': 'Memcachier',
    'msr_big_200m.tr': 'MSR Storage',
    'anonymous_200m.tr': 'Anonymous Application',
    'caida_cache_200m.tr': 'Caida',
}

# %%
def label_map(alg):
    if alg == 'Adaptive-TinyLFU':
        return 'TinyLFU'
    return alg

# %%
def cache_type_to_color(s: str):
    if s in color_map:
        return color_map[s]
    raise Exception(f'color {s} is not defined in color map')

# %%
def top_algorithm_all_trace_csizes(df, objective='byte_hit_rate', k=4):
    top_algs = set()
    df1 = df[~df.cache_type.isin(['GDBT', 'Belady'])].groupby(['trace_file', 'cache_type', 'cache_size'])\
       .agg({objective: 'max'}).reset_index().groupby(['cache_size', 'trace_file'])
    for l, grp in df1:
        top_alg = set(grp.sort_values(by=[objective],  ascending=False).cache_type[0:k])
        top_algs = top_algs.union(top_alg)
    return top_algs

# %%
# find top algorithms
df = common.load_reports()

filter_idx = (
    (df.trace_file == 'traceHK.tr') 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 80000000)
) | ((df.trace_file == 'traceUS.tr') 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 100000000)
    & ((df.cache_type != 'LRUK') | (df.k == '4'))
) | (
    (df.trace_file == 'wc400m.tr') 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 80000000)
    & ((df.cache_type != 'LRUK') | (df.k == '4'))
)

df1 = df[filter_idx].copy()

# %%
top_algs = top_algorithm_all_trace_csizes(df1, k=2)
top_algs
# Out:
# {'Adaptive-TinyLFU', 'LFUDA', 'LRUK', 'LeCaR', 'S4LRU'}

# %%
FONT_SIZE = 26
plt.rc('font', size=FONT_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=FONT_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=FONT_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_SIZE)    # legend fontsize
plt.rc('figure', titlesize=FONT_SIZE)  # fontsize of the figure title
matplotlib.rc('lines', linewidth=3)

# %%
trace = 'traceHK.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR']))  
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 80000000)
#     & ((df.cache_type != 'LRUK') | (df.k == '4'))
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
trace = 'traceUS.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 100000000)
    & ((df.cache_type != 'LRUK') | (df.k == '4'))
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
trace = 'wc400m.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (25000000000 <= df.cache_size)
    & (df.cache_size <= 400000000000)
    & (df.n_warmup == 80000000)
    & ((df.cache_type != 'LRUK') | (df.k == '4'))
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for i, alg in enumerate(['GDBT', 'GDBT']):
    if i:
        grp = df1[(df1.cache_type == alg) & (df1.version == 'dense_sliding_window')].groupby('cache_size').agg({objective: 'max'}).reset_index()
    else:
        grp = df1[(df1.cache_type == alg) & (df1.version != 'dense_sliding_window')].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=3, 
           fontsize='small',
           columnspacing=0.5)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
df2 = df1[(df1.cache_type == 'GDBT') & (df1.cache_size == 100000000000)]

# %%
df2 = df1[(df1.cache_type == 'GDBT') & (df1.cache_size == 400000000000)]

# %%
df2 = df1[(df1.cache_type == 'GDBT') & (df1.cache_size == 25000000000)]

# %%
df3 = df2[df2.byte_hit_rate == df2.byte_hit_rate.max()]

# %%
df3.iloc[0]
# Out:
# alpha                                                                     NaN
# base_edwt_window                                                          NaN
# batch_size                                                             500000
# bias_center                                                               NaN
# bias_point                                                                NaN
# byte_hit_rate                                                        0.428291
# cache_size                                                            2.5e+10
# cache_size_decouple         [[[400,22],[2,5015]],[[400,21],[2,9698]],[[400...
# cache_type                                                               GDBT
# cutoff                                                                    NaN
# dead_penalty                                                              NaN
# forget_penalty_factor                                                     NaN
# forget_window                                                        80000000
# gradient_window                                                           NaN
# k                                                                         NaN
# label                       cache_type: GDBT batch_size: 500000 forget_win...
# learning_rate                                                             0.1
# max_n_past_timestamps                                                      32
# miss_decouple               [[22,[987050,2527254497,987050,2527254497]],[2...
# n_edwt_feature                                                             10
# n_extra_fields                                                              1
# n_gradient_window                                                         NaN
# n_models                                                                  NaN
# n_past_intervals                                                          NaN
# n_warmup                                                                8e+07
# num_iterations                                                             32
# num_threads                                                                 4
# object_hit_rate                                                       0.81003
# objective                                                       byte_hit_rate
# ohr_size_penalty_factor                                                   NaN
# out_sample                                                                NaN
# rebalance                                                                 NaN
# sample_rate                                                               256
# sample_size                                                               NaN
# sample_type                                                               NaN
# segment_byte_hit_rate       0.210327\t0.255452\t0.257836\t0.313589\t0.3228...
# segment_object_hit_rate     0.589276\t0.630130\t0.629934\t0.699178\t0.7185...
# segment_window                                                            NaN
# simulation_time                                                         50081
# static_window                                                             NaN
# step_size                                                              100000
# t                                                                         NaN
# threshold                                                                 NaN
# trace_file                                                          wc400m.tr
# training_sample_interval                                                   64
# uni_size                                                                    0
# version                                                  dense_sliding_window
# window                                                                    NaN
# zero_cost                                                                 NaN
# Name: 11247, dtype: object

# %%
plt.plot(np.array(df3.segment_byte_hit_rate.values[0].split()).astype(float)[:400])
plt.axhline(0.5)
plt.axhline(0.6)
plt.ylim(0.4)

# %%
a = np.array(df3.segment_byte_hit_rate.values[0].split()).astype(float)
np.mean(a.reshape(-1, 3), axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-47efcb635d7c> in <module>
#       1 a = np.array(df3.segment_byte_hit_rate.values[0].split()).astype(float)
# ----> 2 np.mean(a.reshape(-1, 3), axis=1)
#
# ValueError: cannot reshape array of size 400 into shape (3)

# %%
plt.plot(np.mean(a.reshape(10, 40), axis=0))
plt.ylim([0, 1])
# Out:
# (0, 1)

# %%
plt.plot(np.array(df3.segment_byte_hit_rate.values[0].split()).astype(float)[:400])
plt.axhline(0.5)
plt.axhline(0.6)
# plt.ylim(0.4)

# %%
# find top algorithms
df = common.load_reports()

filter_idx = ((
    (df.trace_file == 'memc_200m.tr') 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (250000000 <= df.cache_size)
    & (df.cache_size <= 4000000000)
    & (df.n_warmup == 20000000)
)| (
    (df.trace_file == 'msr_rehash_200m.tr') 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (51200000000 <= df.cache_size)
    & (df.cache_size <= 819200000000)
    & (df.n_warmup == 100000000)
) | (
    (df.trace_file == 'anonymous_200m.tr') 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (1000000000 <= df.cache_size)
    & (df.cache_size <= 16000000000)
    & (df.n_warmup == 20000000)
) | (
    (df.trace_file == 'caida_cache_200m.tr') 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (500000 <= df.cache_size)
    & (df.cache_size <= 8000000)
    & (df.n_warmup == 20000000)
))

df1 = df[filter_idx].copy()

# %%
top_algs = top_algorithm_all_trace_csizes(df1, k=1)
top_algs
# Out:
# {'Adaptive-TinyLFU', 'GDWheel', 'LFUDA', 'LHD', 'LRU', 'LeCaR'}

# %%
top_algs = top_algorithm_all_trace_csizes(df1, k=1)
top_algs
# Out:
# {'Adaptive-TinyLFU', 'LFUDA', 'LRU', 'LeCaR'}

# %%
FONT_SIZE = 34
plt.rc('font', size=FONT_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=FONT_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=FONT_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_SIZE)    # legend fontsize
plt.rc('figure', titlesize=FONT_SIZE)  # fontsize of the figure title
matplotlib.rc('lines', linewidth=3)

# %%
trace = 'memc_200m.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (250000000 <= df.cache_size)
    & (df.cache_size <= 4000000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
trace = 'msr_rehash_200m.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (51200000000 <= df.cache_size)
    & (df.cache_size <= 819200000000)
    & (df.n_warmup == 100000000)
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
trace = 'anonymous_200m.tr'
scale = 1e9
scale_label = 'GiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
    & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (1000000000 <= df.cache_size)
    & (df.cache_size <= 16000000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
trace = 'caida_cache_200m.tr'
scale = 1e6
scale_label = 'MiB'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
     & (~df.cache_type.isin(['Inf', 'BeladySample', 'BeladyTruncate', 'LRU2', 'ThS4LRU', 'ThLRU', 'LR'])) 
    & (500000 <= df.cache_size)
    & (df.cache_size <= 8000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 9))
for alg in list(top_algs)+['Belady', 'GDBT']:
    grp = df1[df1.cache_type == alg].groupby('cache_size').agg({objective: 'max'}).reset_index()
    grp = grp.sort_values(by=['cache_size'])
    if alg == 'GDBT':
        markersize = 14
    else:
        markersize = 10
    ax.semilogx(grp.cache_size/scale,
              1-grp[objective], 
              c=cache_type_to_color(alg), 
              label=label_map(alg), 
              marker=marker_map[alg], 
              markersize=markersize,
              markerfacecolor="None",
              basex=2)

plt.ylim(bottom=0)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel(f'cache size / {scale_label}')
plt.ylabel('byte miss rate')
plt.legend(ncol=2, 
           fontsize='small',
           columnspacing=0.5,
           labelspacing=0.1,
          handletextpad=0.3)
# plt.title(f'{trace_map[trace]}')
plt.show()
