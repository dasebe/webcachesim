# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
from glob import glob
import pathlib
import common

FONT_SIZE = 15
plt.rc('font', size=FONT_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=FONT_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=FONT_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_SIZE)    # legend fontsize
plt.rc('figure', titlesize=FONT_SIZE)  # fontsize of the figure title
matplotlib.rc('lines', linewidth=3)

# %%
trace = 'wc200m.tr'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
    & ((df.cache_type != 'LRUK') | (df.k == '4'))
#     & (df.cache_type == 'LRUK')
#     & (df.cache_type == 'GDBT') 
#     & ((df.cache_type == 'GDBT') | (df.cache_type == 'LRUK'))
    & (df.cache_size == 384000000000)
    & (df.n_warmup == 80000000)
)

df1 = df[filter_idx].copy()

# %%
df1[df1.version == 'reweight'][['byte_hit_rate', 'object_hit_rate', 'ohr_size_penalty_factor']].round(4)
# Out:
#       byte_hit_rate  object_hit_rate ohr_size_penalty_factor
# 5359         0.6050           0.9611                      10
# 5360         0.6525           0.9618                    1.01
# 5361         0.6488           0.9618                     1.1
# 5362         0.6143           0.9613                       4
# 5363         0.6387           0.9617                     1.4
# 5364         0.6519           0.9618                   1.001
# 5365         0.6450           0.9617                     1.2
# 5366         0.6282           0.9615                       2
# 5369         0.7385           0.9491                     NaN

# %%
df_r[['cache_type', 'byte_hit_rate']].round(3)
# Out:
#             cache_type  byte_hit_rate
# 4073               Inf          0.851
# 4149              GDSF          0.671
# 4800                LR          0.600
# 4697               LHD          0.580
# 4105            Belady          0.836
# 4791              GDBT          0.652
# 4924      BeladySample          0.831
# 4726           GDWheel          0.430
# 4770  Adaptive-TinyLFU          0.747
# 4523         AdaptSize          0.341
# 4095             LFUDA          0.724
# 4107              LRUK          0.723
# 4504             LeCaR          0.708
# 4079               LRU          0.701
# 4128               UCB          0.699
# 4093             S4LRU          0.686
# 4112        Hyperbolic          0.647

# %%
df_r = df1[df1['object_hit_rate'] == df1.groupby('cache_type')['object_hit_rate'].transform(max)].sort_values('object_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'object_hit_rate']].round(3)
# Out:
#             cache_type  object_hit_rate
# 4073               Inf            0.966
# 4149              GDSF            0.964
# 4800                LR            0.963
# 4697               LHD            0.963
# 4105            Belady            0.963
# 4791              GDBT            0.962
# 4924      BeladySample            0.961
# 4726           GDWheel            0.956
# 4770  Adaptive-TinyLFU            0.942
# 4523         AdaptSize            0.942
# 4095             LFUDA            0.930
# 4107              LRUK            0.929
# 4504             LeCaR            0.923
# 4079               LRU            0.920
# 4128               UCB            0.919
# 4093             S4LRU            0.915
# 4112        Hyperbolic            0.888

# %%
# df_gdbt = [float(i) for i in df1.loc[3838].segment_byte_hit_rate.split('\t')[:-1]]
# df_lruk = [float(i) for i in df1.loc[3690].segment_byte_hit_rate.split('\t')[:-1]]
# fig, ax = plt.subplots(figsize=(12, 8))
# plt.plot(df_gdbt, marker='*', label='gdbt')
# plt.plot(df_lruk, marker='*', label='lruk')
# plt.legend()
# plt.xlabel('segment id')
# plt.ylabel('hit rate')
# plt.title('segment byte hit rate for wiki trace, segment window = 1m requests')
# plt.ylim([0, 1.])
# plt.show()

# %%
trace = 'memc_200m.tr'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
#     & ((df.cache_type == 'GDBT') | (df.cache_type == 'LRUK'))
#     & ((df.cache_type == 'Belady') | (df.cache_type == 'BeladySample'))
    & (df.cache_size == 4000000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
df1[df1.version == 'reweight'][['byte_hit_rate', 'object_hit_rate', 'ohr_size_penalty_factor']].round(4)
# Out:
#       byte_hit_rate  object_hit_rate ohr_size_penalty_factor
# 5368         0.9438           0.9268                     NaN
# 5379         0.9080           0.9450                      10
# 5380         0.9102           0.9457                       4
# 5382         0.9167           0.9470                     1.4
# 5383         0.9137           0.9465                       2
# 5397         0.9181           0.9472                     1.2
# 5398         0.9200           0.9475                   1.001
# 5399         0.9200           0.9475                    1.01
# 5400         0.9192           0.9474                     1.1

# %%
df1[df1.version == 'hashed_pow']
# Out:
#      alpha batch_size bias_center bias_point  byte_hit_rate    cache_size  \
# 5349   NaN        NaN         NaN        NaN       0.944408  4.000000e+09
#
#      cache_type cutoff dead_penalty gradient_window    ...    segment_window  \
# 5349       GDBT    NaN          NaN          100000    ...               NaN
#
#      simulation_time static_window threshold    trace_file  \
# 5349            4032           NaN  10000000  memc_200m.tr
#
#      training_sample_interval uni_size     version  window zero_cost
# 5349                       64      0.0  hashed_pow     NaN       NaN
#
# [1 rows x 41 columns]

# %%
df_r = df1[df1['byte_hit_rate'] == df1.groupby('cache_type')['byte_hit_rate'].transform(max)]\
            .drop_duplicates('cache_type').sort_values('byte_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'byte_hit_rate']].round(3)
# Out:
#             cache_type  byte_hit_rate
# 4384               Inf          0.966
# 4399            Belady          0.963
# 4939      BeladySample          0.962
# 5331              GDBT          0.946
# 4762  Adaptive-TinyLFU          0.944
# 4489             LeCaR          0.943
# 4385               LRU          0.942
# 4395                LR          0.942
# 4394             LFUDA          0.937
# 4387             S4LRU          0.936
# 4386        Hyperbolic          0.925
# 4397              GDSF          0.912
# 4703               LHD          0.844
# 4599              LRUK          0.696
# 4736           GDWheel          0.674
# 4510         AdaptSize          0.536
# 4390               UCB          0.457

# %%
df_r = df1[df1['object_hit_rate'] == df1.groupby('cache_type')['object_hit_rate'].transform(max)].sort_values('object_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'object_hit_rate']].round(3)
# Out:
#             cache_type  object_hit_rate
# 4384               Inf            0.958
# 4399            Belady            0.954
# 4939      BeladySample            0.953
# 4397              GDSF            0.950
# 5319              GDBT            0.948
# 4703               LHD            0.946
# 4821                LR            0.945
# 4736           GDWheel            0.945
# 4510         AdaptSize            0.934
# 4762  Adaptive-TinyLFU            0.931
# 4489             LeCaR            0.928
# 4385               LRU            0.927
# 4394             LFUDA            0.921
# 4387             S4LRU            0.912
# 4386        Hyperbolic            0.898
# 4599              LRUK            0.792
# 4390               UCB            0.657

# %%
# df_gdbt = [float(i) for i in df.loc[3844].segment_byte_hit_rate.split('\t')[:-1]]
# df_lruk = [float(i) for i in df.loc[3735].segment_byte_hit_rate.split('\t')[:-1]]
# fig, ax = plt.subplots(figsize=(12, 8))
# plt.plot(df_gdbt, marker='*', label='gdbt')
# plt.plot(df_lruk, marker='*', label='lruk')
# plt.legend()
# plt.xlabel('segment id')
# plt.ylabel('hit rate')
# plt.title('segment byte hit rate for wiki trace, segment window = 1m requests')
# plt.ylim([0, 1.])
# plt.show()

# %%
trace = 'msr_big_200m.tr'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
#     & ((df.cache_type == 'Belady') | (df.cache_type == 'BeladySample'))
#         & (df.cache_type == 'GDBT')
    & (df.cache_size == 819200000000)
    & (df.n_warmup == 100000000)
)

df1 = df[filter_idx].copy()

# %%
df1[(df1.cache_type == 'GDBT') & (df1.version == 'lr_like')].num_iterations
# Out:
# 5449    2
# 5450    1
# 5451    1
# 5452    2
# 5453    2
# 5454    1
# 5455    4
# 5456    2
# 5457    2
# 5458    4
# 5459    2
# 5460    4
# 5461    2
# 5462    1
# 5463    2
# 5464    4
# 5465    1
# 5466    1
# 5467    2
# 5468    1
# 5469    4
# 5470    1
# 5471    4
# 5472    1
# 5473    4
# 5474    1
# 5475    4
# 5476    4
# 5477    2
# 5478    4
# Name: num_iterations, dtype: object

# %%
df2 = df1[(df1.cache_type == 'GDBT') & (df1.version == 'lr_like') & (df1.num_threads == '2')]
pd.pivot_table(df2, index='n_gradient_window', columns=['num_iterations', 'objective'], values='byte_hit_rate').round(4)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2 = df1[(df1.cache_type == 'GDBT') & (df1.version == 'lr_like') & (df1.num_threads == '1')]
pd.pivot_table(df2, index='n_gradient_window', columns=['num_iterations', 'objective'], values='byte_hit_rate').round(4)
# Out:
# num_iterations                1                             2                  \
# objective         byte_hit_rate object_hit_rate byte_hit_rate object_hit_rate
# n_gradient_window
# 1                        0.7421          0.7570        0.7798          0.7972
# 2                        0.7355          0.7495        0.7840          0.7959
# 4                        0.7445          0.7522        0.7935          0.8000
# 6                        0.7445          0.7546        0.7931          0.7975
# 8                        0.7319          0.7399        0.7897          0.7888
#
# num_iterations                4
# objective         byte_hit_rate object_hit_rate
# n_gradient_window
# 1                        0.8004          0.8021
# 2                        0.7901          0.7989
# 4                        0.7925          0.8008
# 6                        0.7895          0.7953
# 8                        0.7917          0.7901

# %%
df1[df1.version == 'reweight'][['byte_hit_rate', 'object_hit_rate', 'ohr_size_penalty_factor']].round(4)
# Out:
#       byte_hit_rate  object_hit_rate ohr_size_penalty_factor
# 5371         0.7923           0.8740                     NaN
# 5401         0.8038           0.8956                     1.4
# 5402         0.8033           0.8953                     1.2
# 5403         0.8034           0.8954                     1.1
# 5404         0.8039           0.8956                   1.001
# 5445         0.8025           0.8951                      10
# 5446         0.8021           0.8949                       4
# 5447         0.8037           0.8956                       2
# 5448         0.8032           0.8954                    1.01

# %%
df_r = df1[df1['byte_hit_rate'] == df1.groupby('cache_type')['byte_hit_rate'].transform(max)]\
            .drop_duplicates('cache_type').sort_values('byte_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'byte_hit_rate']].round(3)
# Out:
#             cache_type  byte_hit_rate
# 4183               Inf          0.892
# 4201            Belady          0.892
# 4981      BeladySample          0.871
# 4760  Adaptive-TinyLFU          0.836
# 4835                LR          0.833
# 4740           GDWheel          0.827
# 4718               LHD          0.822
# 4494             LeCaR          0.809
# 5404              GDBT          0.804
# 4257              GDSF          0.803
# 4682              LRUK          0.787
# 4216             LFUDA          0.780
# 4191               LRU          0.779
# 4244        Hyperbolic          0.750
# 4509         AdaptSize          0.632
# 4238               UCB          0.569
# 4230             S4LRU          0.551

# %%
df.loc[4835]
# Out:
# alpha                                                                     NaN
# batch_size                                                                NaN
# bias_center                                                               NaN
# bias_point                                                                NaN
# byte_hit_rate                                                        0.832651
# cache_size                                                          8.192e+11
# cache_type                                                                 LR
# cutoff                                                                    NaN
# dead_penalty                                                              NaN
# gradient_window                                                       1000000
# k                                                                         NaN
# label                       cache_type: LR gradient_window: 1000000 learni...
# learning_rate                                                           1e-06
# max_n_past_timestamps                                                     NaN
# n_edwt_feature                                                            NaN
# n_extra_fields                                                              2
# n_gradient_window                                                         NaN
# n_past_intervals                                                            4
# n_warmup                                                                1e+08
# num_iterations                                                            NaN
# num_threads                                                               NaN
# object_hit_rate                                                      0.918583
# objective                                                     object_hit_rate
# ohr_size_penalty_factor                                                   NaN
# out_sample                                                                NaN
# rebalance                                                                 NaN
# sample_rate                                                                64
# sample_size                                                               NaN
# sample_type                                                               NaN
# segment_byte_hit_rate       0.634726\t0.740547\t0.868587\t0.279095\t0.0930...
# segment_object_hit_rate     0.747170\t0.855600\t0.919615\t0.534924\t0.2874...
# segment_window                                                            NaN
# simulation_time                                                          1884
# static_window                                                             NaN
# threshold                                                            80000000
# trace_file                                                    msr_big_200m.tr
# training_sample_interval                                                   64
# uni_size                                                                    0
# version                                                            known_size
# window                                                                    NaN
# zero_cost                                                                 NaN
# Name: 4835, dtype: object

# %%
df_r = df1[df1['object_hit_rate'] == df1.groupby('cache_type')['object_hit_rate'].transform(max)].sort_values('object_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'object_hit_rate']].round(3)
# Out:
#             cache_type  object_hit_rate
# 4183               Inf            0.944
# 4201            Belady            0.944
# 4981      BeladySample            0.930
# 4835                LR            0.919
# 4760  Adaptive-TinyLFU            0.914
# 4718               LHD            0.913
# 4740           GDWheel            0.912
# 4257              GDSF            0.899
# 5404              GDBT            0.896
# 4494             LeCaR            0.878
# 4682              LRUK            0.866
# 4216             LFUDA            0.860
# 4191               LRU            0.857
# 4244        Hyperbolic            0.847
# 4509         AdaptSize            0.817
# 4238               UCB            0.741
# 4230             S4LRU            0.732

# %%
# fig, ax = plt.subplots(figsize=(12, 8))
# plt.plot(df_gdbt, marker='*', label='gdbt')
# plt.plot(df_lruk, marker='*', label='lruk')
# plt.legend()
# plt.xlabel('segment id')
# plt.ylabel('hit rate')
# plt.title('segment byte hit rate for wiki trace, segment window = 1m requests')
# plt.ylim([0, 1.])
# plt.show()

# %%
trace = 'anonymous_200m.tr'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
#     & (df.cache_type == 'GDBT') 
#     & ((df.cache_type == 'GDBT') | (df.cache_type == 'LRUK'))
    & (df.cache_size == 16000000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
df1[df1.version == 'reweight'][['byte_hit_rate', 'object_hit_rate']].round(4)
# Out:
#       byte_hit_rate  object_hit_rate
# 5367         0.9693           0.9374
# 5420         0.9139           0.9357
# 5422         0.9162           0.9382
# 5423         0.9218           0.9414
# 5424         0.9390           0.9454
# 5425         0.9458           0.9462
# 5426         0.9456           0.9462
# 5427         0.9327           0.9442
# 5428         0.9425           0.9458

# %%
df_r = df1[df1['byte_hit_rate'] == df1.groupby('cache_type')['byte_hit_rate'].transform(max)]\
            .drop_duplicates('cache_type').sort_values('byte_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'byte_hit_rate']].round(3)
# Out:
#             cache_type  byte_hit_rate
# 3968               Inf          0.993
# 4014            Belady          0.981
# 3986      BeladySample          0.979
# 5072              GDBT          0.970
# 4268                LR          0.968
# 4007             LFUDA          0.966
# 4482             LeCaR          0.966
# 3971               LRU          0.965
# 4763  Adaptive-TinyLFU          0.965
# 3980             S4LRU          0.956
# 3979        Hyperbolic          0.954
# 4286              GDSF          0.953
# 4716               LHD          0.943
# 4512         AdaptSize          0.941
# 4666              LRUK          0.932
# 4012               UCB          0.859
# 4752           GDWheel          0.674

# %%
df_r = df1[df1['object_hit_rate'] == df1.groupby('cache_type')['object_hit_rate'].transform(max)].sort_values('object_hit_rate', ascending=False)

# %%
df_r[['cache_type', 'object_hit_rate']].round(3)
# Out:
#             cache_type  object_hit_rate
# 3968               Inf            0.970
# 4014            Belady            0.952
# 3986      BeladySample            0.951
# 4286              GDSF            0.949
# 4716               LHD            0.946
# 4849              GDBT            0.946
# 4268                LR            0.938
# 4512         AdaptSize            0.937
# 4007             LFUDA            0.936
# 4482             LeCaR            0.936
# 4763  Adaptive-TinyLFU            0.935
# 3971               LRU            0.934
# 3980             S4LRU            0.924
# 3979        Hyperbolic            0.922
# 4752           GDWheel            0.901
# 4666              LRUK            0.892
# 4012               UCB            0.764

# %%
trace = 'caida_cache_200m.tr'

df = common.load_reports()
filter_idx = (
    (df.trace_file == trace) 
    & (df.uni_size == 0)
#     & (df.cache_type == 'GDBT') 
#     & ((df.cache_type == 'GDBT') | (df.cache_type == 'LRUK'))
    & (df.cache_size == 8000000)
    & (df.n_warmup == 20000000)
)

df1 = df[filter_idx].copy()

# %%
df1[df1.version == 'reweight'][['byte_hit_rate', 'object_hit_rate']].round(4)
# Out:
#       byte_hit_rate  object_hit_rate
# 5370         0.9423           0.9423
# 5429         0.9423           0.9423
# 5430         0.9423           0.9423
# 5431         0.9423           0.9423
# 5432         0.9423           0.9423
# 5433         0.9423           0.9423
# 5434         0.9423           0.9423
# 5435         0.9423           0.9423
# 5440         0.9423           0.9423

# %%
df1[df1.version == 'hashed_pow']
# Out:
#      alpha batch_size bias_center bias_point  byte_hit_rate  cache_size  \
# 5354   NaN        NaN         NaN        NaN       0.942252   8000000.0
#
#      cache_type cutoff dead_penalty gradient_window    ...    segment_window  \
# 5354       GDBT    NaN          NaN          100000    ...               NaN
#
#      simulation_time static_window threshold           trace_file  \
# 5354            5710           NaN  10000000  caida_cache_200m.tr
#
#      training_sample_interval uni_size     version  window zero_cost
# 5354                       64      0.0  hashed_pow     NaN       NaN
#
# [1 rows x 40 columns]

# %%
df_r = df1[df1['byte_hit_rate'] == df1.groupby('cache_type')['byte_hit_rate'].transform(max)].sort_values('byte_hit_rate', ascending=False).drop_duplicates('cache_type')

# %%
df_r[['cache_type', 'byte_hit_rate']].round(3)
# Out:
#             cache_type  byte_hit_rate
# 4396               Inf          0.972
# 4411            Belady          0.957
# 4910      BeladySample          0.957
# 5346              GDBT          0.943
# 4768  Adaptive-TinyLFU          0.935
# 4486             LeCaR          0.935
# 4403               LRU          0.935
# 4443             S4LRU          0.930
# 4450                LR          0.925
# 4721           GDWheel          0.924
# 4456        Hyperbolic          0.918
# 4430             LFUDA          0.917
# 4462              GDSF          0.915
# 4684               LHD          0.911
# 4516         AdaptSize          0.784
# 4564              LRUK          0.315
# 4451               UCB          0.275

# %%
df_r = df1[df1['object_hit_rate'] == df1.groupby('cache_type')['object_hit_rate'].transform(max)].sort_values('object_hit_rate', ascending=False).drop_duplicates('cache_type')
